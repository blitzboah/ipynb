# %%
import pandas as pd
gdf = pd.read_csv('dataset.csv')
gdf.head()
# Out:
#    Unnamed: 0                track_id  ... time_signature track_genre
# 0           0  5SuOikwiRyPMVoIQDJUgSV  ...              4    acoustic
# 1           1  4qPNDBW1i3p13qLCt0Ki3A  ...              4    acoustic
# 2           2  1iJBSr7s7jYXzM8EGcbK5b  ...              4    acoustic
# 3           3  6lfxq3CG4xtTiEg7opyCyx  ...              3    acoustic
# 4           4  5vjLSffimiIP26QG5WcN2K  ...              4    acoustic
#
# [5 rows x 21 columns]

# %%
pd.crosstab(index=cat_data['artists'], columns=cat_data['track_genre'], margins=True)
# Out:
# track_genre                                         acoustic  ...     All
# artists                                                       ...
# !nvite                                                     0  ...       2
# "Puppy Dog Pals" Cast                                      0  ...       2
# "Weird Al" Yankovic                                        0  ...      15
# #Kids;Nursery Rhymes;Nursery Rhymes and Kids Songs         0  ...       1
# $affie                                                     0  ...       1
# ...                                                      ...  ...     ...
# 黃妃                                                         0  ...       2
# 黃小琥                                                        0  ...       1
# 黃敏華                                                        0  ...       1
# 龍藏Ryuzo                                                    0  ...       2
# All                                                     1000  ...  113999
#
# ...
